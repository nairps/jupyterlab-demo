# %% [markdown]
# # Calculating pi using Monte Carlo methods

# %% [markdown]
# ## 1. Document the relevant formulas in a new cell

# %% [markdown]
#  - square area: $s = (2 r)^2$
#  - circle area: $c = \pi r^2$
#  - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
#  - $\pi = 4 * c/s$

# %% [markdown]
# ## 2 An image to explain the concept:

# %% [markdown]
# ![Darts](https://coderefinery.github.io/jupyter/img/darts.svg)

# %% [markdown]
# ## 3. Import random module:

# %%
import random

# %% [markdown]
# ## 4. Initialize the number of points:

# %%
num_points = 1000
print(num_points)
# Out:
# 1000

# %% [markdown]
# ## 5. Throwing darts:

# %%
points = []
hits = 0
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x, y, True))
    else:
        points.append((x, y, False))

# %% [markdown]
# ## 6. Plot results:

# %%
# %matplotlib inline
from matplotlib import pyplot
x, y, colors = zip(*points)
pyplot.scatter(x, y, c=colors)

# %% [markdown]
# ## 7. Compute final estimate of pi:

# %%
fraction = hits / num_points
4 * fraction
# Out:
# 3.076
